# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
import math
import os
import csv
from datetime import datetime



# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build URL using the weather API
url="http://api.openweathermap.org/data/2.5/weather?"

#parameter to take the info to the url  
query_url = f"{url}appid={weather_api_key}&q="

# create dictionary to append the data for it 
city_dict = {
    "City": [],
    "Lat": [],
    "Lng":[],
    "Max temp":[],
    "Humidity":[],
    "Cloudiness":[],
    "Wind speed":[],
    "Country":[],
    "Date":[]
}
print("Beginning Data Retrieval")
print("-------------------------")
count = 0

#loop through the cities 
for city in cities:

    #Run request
    city_response=requests.get(query_url + city).json()
    if city_response["cod"] == 200 :
        print(f"Processing record {count%50} Set {(math.floor(count/50)+1)} : | {city}")
        city_dict['City'].append(city_response["name"])
        city_dict['Lat'].append(city_response["coord"]["lat"])
        city_dict['Lng'].append(city_response["coord"]["lon"])
        city_dict['Max temp'].append(city_response["main"]["temp_max"])
        city_dict['Humidity'].append(city_response["main"]["humidity"])
        city_dict['Cloudiness'].append(city_response["clouds"]["all"])
        city_dict['Wind speed'].append(city_response["wind"]["speed"])
        city_dict['Country'].append(city_response["sys"]["country"])
        city_dict['Date'].append(city_response["dt"])

    else:
        print(f"{city_response['message']}. Skipping...")
    count += 1

    # 60 seconds sleep when reach 50
    if count % 50 == 0:
        time.sleep(60)
print("-------------------------")
print("Data Retrieval Complete ")
print("-------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing record 0 Set 1 : | dhidhdhoo
# Processing record 1 Set 1 : | moron
# Processing record 2 Set 1 : | san patricio
# Processing record 3 Set 1 : | quatre cocos
# Processing record 4 Set 1 : | clyde river
# Processing record 5 Set 1 : | chuy
# Processing record 6 Set 1 : | karlskoga
# Processing record 7 Set 1 : | severo-kurilsk
# Processing record 8 Set 1 : | samana
# city not found. Skipping...
# Processing record 10 Set 1 : | tuktoyaktuk
# Processing record 11 Set 1 : | anadyr
# Processing record 12 Set 1 : | makakilo city
# Processing record 13 Set 1 : | esperance
# Processing record 14 Set 1 : | bluff
# Processing record 15 Set 1 : | cape town
# city not found. Skipping...
# city not found. Skipping...
# Processing record 18 Set 1 : | saint george
# city not found. Skipping...
# Processing record 20 Set 1 : | port macquarie
# Processing record 21 Set 1 : | ushuaia
# Processing record 22 Set 1 : | faya
# Processing record 23 Set 1 : | atar
# Processing record 24 Set 1 : | baoro
# Processing record 25 Set 1 : | ribeira grande
# Processing record 26 Set 1 : | thinadhoo
# Processing record 27 Set 1 : | georgetown
# Processing record 28 Set 1 : | port hedland
# Processing record 29 Set 1 : | hobart
# Processing record 30 Set 1 : | bambous virieux
# Processing record 31 Set 1 : | new norfolk
# Processing record 32 Set 1 : | albany
# Processing record 33 Set 1 : | kazachinskoye
# Processing record 34 Set 1 : | tuatapere
# Processing record 35 Set 1 : | grand gaube
# Processing record 36 Set 1 : | harper
# city not found. Skipping...
# Processing record 38 Set 1 : | sabang
# Processing record 39 Set 1 : | borba
# Processing record 40 Set 1 : | nanortalik
# Processing record 41 Set 1 : | mataura
# city not found. Skipping...
# Processing record 43 Set 1 : | kodiak
# Processing record 44 Set 1 : | pitimbu
# city not found. Skipping...
# Processing record 46 Set 1 : | hilo
# Processing record 47 Set 1 : | riyadh
# Processing record 48 Set 1 : | westport
# Processing record 49 Set 1 : | longyearbyen
# Processing record 0 Set 2 : | chapais
# Processing record 1 Set 2 : | pak chong
# Processing record 2 Set 2 : | asfi
# Processing record 3 Set 2 : | hermanus
# Processing record 4 Set 2 : | mar del plata
# Processing record 5 Set 2 : | kapaa
# Processing record 6 Set 2 : | nortelandia
# Processing record 7 Set 2 : | airai
# Processing record 8 Set 2 : | young
# Processing record 9 Set 2 : | banjarmasin
# Processing record 10 Set 2 : | busselton
# Processing record 11 Set 2 : | pacific grove
# Processing record 12 Set 2 : | bukavu
# Processing record 13 Set 2 : | port alfred
# Processing record 14 Set 2 : | torbay
# Processing record 15 Set 2 : | chifeng
# Processing record 16 Set 2 : | quelimane
# Processing record 17 Set 2 : | hami
# Processing record 18 Set 2 : | bang saphan
# Processing record 19 Set 2 : | bhuban
# city not found. Skipping...
# Processing record 21 Set 2 : | concepcion del uruguay
# Processing record 22 Set 2 : | port elizabeth
# Processing record 23 Set 2 : | barrow
# Processing record 24 Set 2 : | paracuru
# Processing record 25 Set 2 : | mount isa
# Processing record 26 Set 2 : | springbok
# Processing record 27 Set 2 : | klaksvik
# city not found. Skipping...
# Processing record 29 Set 2 : | karpathos
# Processing record 30 Set 2 : | vaini
# Processing record 31 Set 2 : | bredasdorp
# Processing record 32 Set 2 : | edea
# Processing record 33 Set 2 : | punta arenas
# Processing record 34 Set 2 : | leningradskiy
# Processing record 35 Set 2 : | butaritari
# Processing record 36 Set 2 : | andrews
# Processing record 37 Set 2 : | jawhar
# Processing record 38 Set 2 : | stornoway
# Processing record 39 Set 2 : | clovis
# Processing record 40 Set 2 : | victoria
# Processing record 41 Set 2 : | chaman
# Processing record 42 Set 2 : | kumluca
# Processing record 43 Set 2 : | puerto ayora
# Processing record 44 Set 2 : | jamestown
# Processing record 45 Set 2 : | yellowknife
# Processing record 46 Set 2 : | sumenep
# Processing record 47 Set 2 : | guerrero negro
# Processing record 48 Set 2 : | souillac
# Processing record 49 Set 2 : | hasaki
# Processing record 0 Set 3 : | okhotsk
# Processing record 1 Set 3 : | upernavik
# Processing record 2 Set 3 : | luanda
# Processing record 3 Set 3 : | concordia
# Processing record 4 Set 3 : | gazli
# Processing record 5 Set 3 : | provideniya
# Processing record 6 Set 3 : | adre
# Processing record 7 Set 3 : | bulach
# Processing record 8 Set 3 : | lasa
# Processing record 9 Set 3 : | ulaangom
# Processing record 10 Set 3 : | capacuaro
# city not found. Skipping...
# Processing record 12 Set 3 : | maldonado
# Processing record 13 Set 3 : | tiksi
# Processing record 14 Set 3 : | qaqortoq
# Processing record 15 Set 3 : | mbekenyera
# Processing record 16 Set 3 : | harnosand
# Processing record 17 Set 3 : | poum
# Processing record 18 Set 3 : | antofagasta
# Processing record 19 Set 3 : | nagato
# Processing record 20 Set 3 : | narsaq
# city not found. Skipping...
# Processing record 22 Set 3 : | castro
# Processing record 23 Set 3 : | yulara
# city not found. Skipping...
# Processing record 25 Set 3 : | saint-philippe
# Processing record 26 Set 3 : | ciudad bolivar
# Processing record 27 Set 3 : | inhambane
# Processing record 28 Set 3 : | carnarvon
# Processing record 29 Set 3 : | thompson
# city not found. Skipping...
# Processing record 31 Set 3 : | melbu
# Processing record 32 Set 3 : | cidreira
# Processing record 33 Set 3 : | hithadhoo
# Processing record 34 Set 3 : | shingu
# Processing record 35 Set 3 : | rikitea
# Processing record 36 Set 3 : | ballina
# Processing record 37 Set 3 : | kahului
# Processing record 38 Set 3 : | santo domingo
# city not found. Skipping...
# Processing record 40 Set 3 : | atuona
# Processing record 41 Set 3 : | nikolskoye
# Processing record 42 Set 3 : | dingle
# Processing record 43 Set 3 : | baghdad
# Processing record 44 Set 3 : | saint-augustin
# Processing record 45 Set 3 : | mareeba
# Processing record 46 Set 3 : | arraial do cabo
# city not found. Skipping...
# Processing record 48 Set 3 : | ramhormoz
# Processing record 49 Set 3 : | ancud
# Processing record 0 Set 4 : | mackay
# city not found. Skipping...
# Processing record 2 Set 4 : | guanare
# Processing record 3 Set 4 : | shenzhen
# Processing record 4 Set 4 : | cabo san lucas
# Processing record 5 Set 4 : | east london
# Processing record 6 Set 4 : | elizabeth city
# Processing record 7 Set 4 : | chlum u trebone
# Processing record 8 Set 4 : | antalaha
# Processing record 9 Set 4 : | pisco
# Processing record 10 Set 4 : | kloulklubed
# Processing record 11 Set 4 : | plettenberg bay
# Processing record 12 Set 4 : | turtas
# Processing record 13 Set 4 : | lompoc
# Processing record 14 Set 4 : | podgornoye
# Processing record 15 Set 4 : | alyangula
# Processing record 16 Set 4 : | meulaboh
# Processing record 17 Set 4 : | emba
# Processing record 18 Set 4 : | waipawa
# Processing record 19 Set 4 : | kysyl-syr
# Processing record 20 Set 4 : | gberia fotombu
# Processing record 21 Set 4 : | constitucion
# Processing record 22 Set 4 : | maceio
# Processing record 23 Set 4 : | maragogi
# Processing record 24 Set 4 : | zhezkazgan
# Processing record 25 Set 4 : | bud
# Processing record 26 Set 4 : | atherton
# Processing record 27 Set 4 : | lebu
# Processing record 28 Set 4 : | oxford
# Processing record 29 Set 4 : | santa lucia
# Processing record 30 Set 4 : | kontagora
# Processing record 31 Set 4 : | san quintin
# Processing record 32 Set 4 : | mahebourg
# Processing record 33 Set 4 : | solnechnyy
# city not found. Skipping...
# Processing record 35 Set 4 : | khash
# Processing record 36 Set 4 : | vyartsilya
# Processing record 37 Set 4 : | qaanaaq
# Processing record 38 Set 4 : | luderitz
# Processing record 39 Set 4 : | cockburn town
# Processing record 40 Set 4 : | komsomolskiy
# Processing record 41 Set 4 : | zelenoborskiy
# Processing record 42 Set 4 : | luwuk
# Processing record 43 Set 4 : | creel
# Processing record 44 Set 4 : | denpasar
# Processing record 45 Set 4 : | seymchan
# Processing record 46 Set 4 : | awjilah
# Processing record 47 Set 4 : | killybegs
# Processing record 48 Set 4 : | avera
# Processing record 49 Set 4 : | amahai
# Processing record 0 Set 5 : | werda
# Processing record 1 Set 5 : | soyo
# Processing record 2 Set 5 : | kem
# Processing record 3 Set 5 : | horta
# Processing record 4 Set 5 : | tasiilaq
# Processing record 5 Set 5 : | husavik
# Processing record 6 Set 5 : | nuuk
# Processing record 7 Set 5 : | pevek
# Processing record 8 Set 5 : | qui nhon
# city not found. Skipping...
# Processing record 10 Set 5 : | berberati
# Processing record 11 Set 5 : | avarua
# Processing record 12 Set 5 : | takayama
# Processing record 13 Set 5 : | inirida
# Processing record 14 Set 5 : | plouzane
# Processing record 15 Set 5 : | saskylakh
# Processing record 16 Set 5 : | amot
# Processing record 17 Set 5 : | yar-sale
# city not found. Skipping...
# Processing record 19 Set 5 : | kavaratti
# Processing record 20 Set 5 : | san ignacio
# Processing record 21 Set 5 : | srednekolymsk
# Processing record 22 Set 5 : | chokurdakh
# Processing record 23 Set 5 : | colares
# city not found. Skipping...
# Processing record 25 Set 5 : | aklavik
# Processing record 26 Set 5 : | keti bandar
# city not found. Skipping...
# city not found. Skipping...
# Processing record 29 Set 5 : | west wendover
# Processing record 30 Set 5 : | kindersley
# Processing record 31 Set 5 : | tilichiki
# Processing record 32 Set 5 : | buala
# Processing record 33 Set 5 : | dikson
# Processing record 34 Set 5 : | faanui
# Processing record 35 Set 5 : | portoferraio
# Processing record 36 Set 5 : | shelburne
# Processing record 37 Set 5 : | namibe
# city not found. Skipping...
# Processing record 39 Set 5 : | marienburg
# Processing record 40 Set 5 : | harlingen
# Processing record 41 Set 5 : | moose factory
# Processing record 42 Set 5 : | ous
# Processing record 43 Set 5 : | hofn
# Processing record 44 Set 5 : | vestmannaeyjar
# Processing record 45 Set 5 : | kaitangata
# Processing record 46 Set 5 : | nome
# Processing record 47 Set 5 : | nemuro
# Processing record 48 Set 5 : | iracoubo
# Processing record 49 Set 5 : | cabedelo
# Processing record 0 Set 6 : | ust-kuyga
# Processing record 1 Set 6 : | mayumba
# Processing record 2 Set 6 : | eureka
# Processing record 3 Set 6 : | conceicao do araguaia
# Processing record 4 Set 6 : | sitka
# Processing record 5 Set 6 : | ouegoa
# Processing record 6 Set 6 : | fayaoue
# Processing record 7 Set 6 : | chara
# Processing record 8 Set 6 : | toul
# Processing record 9 Set 6 : | laguna
# Processing record 10 Set 6 : | geraldton
# Processing record 11 Set 6 : | fairbanks
# city not found. Skipping...
# Processing record 13 Set 6 : | senno
# Processing record 14 Set 6 : | nova aurora
# Processing record 15 Set 6 : | ugoofaaru
# Processing record 16 Set 6 : | tara
# Processing record 17 Set 6 : | bathsheba
# Processing record 18 Set 6 : | vardo
# Processing record 19 Set 6 : | green river
# Processing record 20 Set 6 : | bilma
# Processing record 21 Set 6 : | tessalit
# Processing record 22 Set 6 : | cedar city
# Processing record 23 Set 6 : | dabou
# Processing record 24 Set 6 : | cherskiy
# Processing record 25 Set 6 : | martinsville
# Processing record 26 Set 6 : | nyimba
# Processing record 27 Set 6 : | haines junction
# Processing record 28 Set 6 : | north bend
# Processing record 29 Set 6 : | sibolga
# Processing record 30 Set 6 : | kadoma
# Processing record 31 Set 6 : | khatanga
# Processing record 32 Set 6 : | batsfjord
# city not found. Skipping...
# Processing record 34 Set 6 : | belaya gora
# Processing record 35 Set 6 : | bandarbeyla
# Processing record 36 Set 6 : | vila velha
# Processing record 37 Set 6 : | waingapu
# Processing record 38 Set 6 : | ayan
# city not found. Skipping...
# Processing record 40 Set 6 : | anloga
# Processing record 41 Set 6 : | bethel
# Processing record 42 Set 6 : | xining
# Processing record 43 Set 6 : | healdsburg
# Processing record 44 Set 6 : | iqaluit
# Processing record 45 Set 6 : | schoneiche
# Processing record 46 Set 6 : | salalah
# Processing record 47 Set 6 : | lata
# Processing record 48 Set 6 : | hualmay
# Processing record 49 Set 6 : | puerto carreno
# Processing record 0 Set 7 : | ponta do sol
# Processing record 1 Set 7 : | gusinoye ozero
# Processing record 2 Set 7 : | taloqan
# Processing record 3 Set 7 : | coihaique
# Processing record 4 Set 7 : | portalegre
# Processing record 5 Set 7 : | sakakah
# Processing record 6 Set 7 : | caravelas
# Processing record 7 Set 7 : | henties bay
# city not found. Skipping...
# Processing record 9 Set 7 : | huarmey
# Processing record 10 Set 7 : | lagoa
# Processing record 11 Set 7 : | panzhihua
# Processing record 12 Set 7 : | shaowu
# Processing record 13 Set 7 : | banff
# Processing record 14 Set 7 : | porangatu
# Processing record 15 Set 7 : | norman wells
# Processing record 16 Set 7 : | beringovskiy
# Processing record 17 Set 7 : | esmeraldas
# city not found. Skipping...
# Processing record 19 Set 7 : | isangel
# Processing record 20 Set 7 : | caldas novas
# Processing record 21 Set 7 : | zakamensk
# Processing record 22 Set 7 : | ahuimanu
# Processing record 23 Set 7 : | san isidro
# Processing record 24 Set 7 : | uchiza
# city not found. Skipping...
# Processing record 26 Set 7 : | naze
# Processing record 27 Set 7 : | bejar
# Processing record 28 Set 7 : | oktyabrskoye
# Processing record 29 Set 7 : | conde
# Processing record 30 Set 7 : | iralaya
# Processing record 31 Set 7 : | aberdeen
# Processing record 32 Set 7 : | jaca
# Processing record 33 Set 7 : | banda aceh
# city not found. Skipping...
# Processing record 35 Set 7 : | san andres
# city not found. Skipping...
# Processing record 37 Set 7 : | baruun-urt
# Processing record 38 Set 7 : | codrington
# Processing record 39 Set 7 : | aksarka
# Processing record 40 Set 7 : | adrar
# Processing record 41 Set 7 : | cardenas
# Processing record 42 Set 7 : | labuhan
# Processing record 43 Set 7 : | batagay-alyta
# Processing record 44 Set 7 : | luba
# Processing record 45 Set 7 : | boulder
# Processing record 46 Set 7 : | kristinehamn
# Processing record 47 Set 7 : | mankera
# Processing record 48 Set 7 : | abu kamal
# Processing record 49 Set 7 : | mahajanga
# Processing record 0 Set 8 : | ambon
# Processing record 1 Set 8 : | vostok
# Processing record 2 Set 8 : | vao
# Processing record 3 Set 8 : | surovatikha
# Processing record 4 Set 8 : | egvekinot
# Processing record 5 Set 8 : | dunedin
# Processing record 6 Set 8 : | ilo
# Processing record 7 Set 8 : | acapulco
# Processing record 8 Set 8 : | talnakh
# Processing record 9 Set 8 : | aktau
# Processing record 10 Set 8 : | broome
# Processing record 11 Set 8 : | ganzhou
# Processing record 12 Set 8 : | taltal
# Processing record 13 Set 8 : | san luis
# Processing record 14 Set 8 : | aswan
# Processing record 15 Set 8 : | ahipara
# Processing record 16 Set 8 : | port lincoln
# Processing record 17 Set 8 : | trelew
# city not found. Skipping...
# city not found. Skipping...
# city not found. Skipping...
# Processing record 21 Set 8 : | tandil
# Processing record 22 Set 8 : | bani
# Processing record 23 Set 8 : | majene
# Processing record 24 Set 8 : | wagar
# Processing record 25 Set 8 : | kande
# Processing record 26 Set 8 : | jaumave
# Processing record 27 Set 8 : | dondo
# city not found. Skipping...
# Processing record 29 Set 8 : | campbell river
# Processing record 30 Set 8 : | ola
# Processing record 31 Set 8 : | margate
# Processing record 32 Set 8 : | damghan
# Processing record 33 Set 8 : | biak
# Processing record 34 Set 8 : | kupang
# Processing record 35 Set 8 : | katsuura
# Processing record 36 Set 8 : | sao filipe
# Processing record 37 Set 8 : | forbes
# Processing record 38 Set 8 : | maningrida
# Processing record 39 Set 8 : | uzunovo
# Processing record 40 Set 8 : | usinsk
# Processing record 41 Set 8 : | gat
# Processing record 42 Set 8 : | alice springs
# Processing record 43 Set 8 : | bitung
# Processing record 44 Set 8 : | samarai
# Processing record 45 Set 8 : | tornio
# Processing record 46 Set 8 : | gizo
# Processing record 47 Set 8 : | oranjemund
# Processing record 48 Set 8 : | falun
# Processing record 49 Set 8 : | kruisfontein
# Processing record 0 Set 9 : | vypolzovo
# Processing record 1 Set 9 : | garden city
# Processing record 2 Set 9 : | nieves
# city not found. Skipping...
# Processing record 4 Set 9 : | mpanda
# Processing record 5 Set 9 : | nakhon thai
# Processing record 6 Set 9 : | huizhou
# Processing record 7 Set 9 : | gogrial
# Processing record 8 Set 9 : | bengkulu
# Processing record 9 Set 9 : | adolfo lopez mateos
# Processing record 10 Set 9 : | pavlysh
# Processing record 11 Set 9 : | marawi
# Processing record 12 Set 9 : | san juan
# Processing record 13 Set 9 : | roald
# Processing record 14 Set 9 : | berezovyy
# Processing record 15 Set 9 : | shestakovo
# Processing record 16 Set 9 : | evensk
# Processing record 17 Set 9 : | benton harbor
# Processing record 18 Set 9 : | villarrica
# Processing record 19 Set 9 : | taoudenni
# Processing record 20 Set 9 : | marsa matruh
# Processing record 21 Set 9 : | havre-saint-pierre
# Processing record 22 Set 9 : | padang
# Processing record 23 Set 9 : | brandon
# Processing record 24 Set 9 : | lavrentiya
# Processing record 25 Set 9 : | nishihara
# Processing record 26 Set 9 : | santa rosalia
# Processing record 27 Set 9 : | khuldabad
# Processing record 28 Set 9 : | macon
# Processing record 29 Set 9 : | dumas
# city not found. Skipping...
# Processing record 31 Set 9 : | tamale
# Processing record 32 Set 9 : | kolondieba
# Processing record 33 Set 9 : | seda
# Processing record 34 Set 9 : | fare
# Processing record 35 Set 9 : | lethem
# Processing record 36 Set 9 : | omboue
# Processing record 37 Set 9 : | xuddur
# Processing record 38 Set 9 : | champerico
# Processing record 39 Set 9 : | hearst
# Processing record 40 Set 9 : | kemi
# Processing record 41 Set 9 : | paamiut
# Processing record 42 Set 9 : | nizwa
# Processing record 43 Set 9 : | zhashkiv
# Processing record 44 Set 9 : | diego de almagro
# Processing record 45 Set 9 : | rio grande
# Processing record 46 Set 9 : | mount gambier
# Processing record 47 Set 9 : | olafsvik
# Processing record 48 Set 9 : | hay river
# Processing record 49 Set 9 : | kintinku
# Processing record 0 Set 10 : | yeppoon
# Processing record 1 Set 10 : | buchanan
# Processing record 2 Set 10 : | cayenne
# Processing record 3 Set 10 : | saldanha
# Processing record 4 Set 10 : | zabaykalsk
# Processing record 5 Set 10 : | dryden
# Processing record 6 Set 10 : | dalby
# Processing record 7 Set 10 : | north myrtle beach
# Processing record 8 Set 10 : | yoichi
# city not found. Skipping...
# Processing record 10 Set 10 : | itoman
# city not found. Skipping...
# Processing record 12 Set 10 : | bubaque
# Processing record 13 Set 10 : | lake city
# city not found. Skipping...
# Processing record 15 Set 10 : | kavieng
# Processing record 16 Set 10 : | labrea
# Processing record 17 Set 10 : | yafran
# Processing record 18 Set 10 : | jalu
# Processing record 19 Set 10 : | cuddapah
# Processing record 20 Set 10 : | katherine
# Processing record 21 Set 10 : | altamira
# city not found. Skipping...
# city not found. Skipping...
# Processing record 24 Set 10 : | matamoros
# Processing record 25 Set 10 : | vangaindrano
# Processing record 26 Set 10 : | yinchuan
# Processing record 27 Set 10 : | oistins
# Processing record 28 Set 10 : | teahupoo
# Processing record 29 Set 10 : | salinopolis
# Processing record 30 Set 10 : | pilar
# Processing record 31 Set 10 : | wajima
# Processing record 32 Set 10 : | camacha
# Processing record 33 Set 10 : | honningsvag
# Processing record 34 Set 10 : | khor
# Processing record 35 Set 10 : | touros
# Processing record 36 Set 10 : | hamilton
# Processing record 37 Set 10 : | pangnirtung
# Processing record 38 Set 10 : | ust-koksa
# Processing record 39 Set 10 : | whitehorse
# city not found. Skipping...
# Processing record 41 Set 10 : | leh
# Processing record 42 Set 10 : | xuchang
# city not found. Skipping...
# Processing record 44 Set 10 : | mahina
# Processing record 45 Set 10 : | saint-joseph
# Processing record 46 Set 10 : | svetlogorsk
# Processing record 47 Set 10 : | sao joao da barra
# Processing record 48 Set 10 : | andenes
# Processing record 49 Set 10 : | kenmare
# Processing record 0 Set 11 : | tura
# Processing record 1 Set 11 : | lagos
# Processing record 2 Set 11 : | damietta
# Processing record 3 Set 11 : | pechenga
# Processing record 4 Set 11 : | kununurra
# Processing record 5 Set 11 : | miraflores
# Processing record 6 Set 11 : | tortoli
# city not found. Skipping...
# city not found. Skipping...
# Processing record 9 Set 11 : | inuvik
# Processing record 10 Set 11 : | ossora
# Processing record 11 Set 11 : | midland
# Processing record 12 Set 11 : | mayo
# Processing record 13 Set 11 : | lakhdenpokhya
# Processing record 14 Set 11 : | turukhansk
# Processing record 15 Set 11 : | waitati
# city not found. Skipping...
# Processing record 17 Set 11 : | alofi
# Processing record 18 Set 11 : | thouars
# Processing record 19 Set 11 : | meihekou
# Processing record 20 Set 11 : | cap malheureux
# Processing record 21 Set 11 : | abonnema
# city not found. Skipping...
# city not found. Skipping...
# Processing record 24 Set 11 : | mama
# Processing record 25 Set 11 : | katobu
# Processing record 26 Set 11 : | indi
# Processing record 27 Set 11 : | tabas
# Processing record 28 Set 11 : | viedma
# Processing record 29 Set 11 : | burgeo
# Processing record 30 Set 11 : | songea
# Processing record 31 Set 11 : | san angelo
# Processing record 32 Set 11 : | guilin
# city not found. Skipping...
# Processing record 34 Set 11 : | muncar
# Processing record 35 Set 11 : | eyemouth
# Processing record 36 Set 11 : | yerofey pavlovich
# Processing record 37 Set 11 : | puerto madryn
# city not found. Skipping...
# Processing record 39 Set 11 : | imeni zhelyabova
# Processing record 40 Set 11 : | berlevag
# Processing record 41 Set 11 : | lincoln
# Processing record 42 Set 11 : | piacabucu
# Processing record 43 Set 11 : | lixourion
# city not found. Skipping...
# Processing record 45 Set 11 : | suntar
# Processing record 46 Set 11 : | brae
# Processing record 47 Set 11 : | kailua
# Processing record 48 Set 11 : | dakar
# Processing record 49 Set 11 : | flic en flac
# Processing record 0 Set 12 : | pasni
# city not found. Skipping...
# city not found. Skipping...
# Processing record 3 Set 12 : | guatire
# Processing record 4 Set 12 : | bowen
# Processing record 5 Set 12 : | salym
# Processing record 6 Set 12 : | kabwe
# Processing record 7 Set 12 : | la ronge
# Processing record 8 Set 12 : | voznesenye
# Processing record 9 Set 12 : | alta floresta
# city not found. Skipping...
# Processing record 11 Set 12 : | talavera
# city not found. Skipping...
# city not found. Skipping...
# Processing record 14 Set 12 : | xichang
# Processing record 15 Set 12 : | amapa
# Processing record 16 Set 12 : | grindavik
# Processing record 17 Set 12 : | the valley
# Processing record 18 Set 12 : | hambantota
# Processing record 19 Set 12 : | zhigansk
# Processing record 20 Set 12 : | lebanon
# Processing record 21 Set 12 : | hope
# Processing record 22 Set 12 : | gamba
# Processing record 23 Set 12 : | madaoua
# Processing record 24 Set 12 : | bilokurakyne
# Processing record 25 Set 12 : | kutum
# Processing record 26 Set 12 : | sept-iles
# Processing record 27 Set 12 : | aksu
# Processing record 28 Set 12 : | wilmington island
# Processing record 29 Set 12 : | balykshi
# Processing record 30 Set 12 : | singapore
# Processing record 31 Set 12 : | tabuk
# city not found. Skipping...
# Processing record 33 Set 12 : | afua
# Processing record 34 Set 12 : | morgan city
# Processing record 35 Set 12 : | partyzany
# Processing record 36 Set 12 : | maitum
# Processing record 37 Set 12 : | rocha
# Processing record 38 Set 12 : | verkhovyna
# Processing record 39 Set 12 : | tiarei
# Processing record 40 Set 12 : | arlit
# Processing record 41 Set 12 : | vicente guerrero
# city not found. Skipping...
# city not found. Skipping...
# Processing record 44 Set 12 : | la rioja
# Processing record 45 Set 12 : | sorong
# Processing record 46 Set 12 : | kang
# Processing record 47 Set 12 : | batticaloa
# Processing record 48 Set 12 : | rancagua
# Processing record 49 Set 12 : | mabaruma
# Processing record 0 Set 13 : | neiafu
# Processing record 1 Set 13 : | muros
# Processing record 2 Set 13 : | vila franca do campo
# Processing record 3 Set 13 : | tsabong
# Processing record 4 Set 13 : | berwick
# Processing record 5 Set 13 : | shizunai
# Processing record 6 Set 13 : | kaduqli
# Processing record 7 Set 13 : | ignatovka
# Processing record 8 Set 13 : | sorland
# Processing record 9 Set 13 : | pampas
# city not found. Skipping...
# Processing record 11 Set 13 : | puerto del rosario
# Processing record 12 Set 13 : | tokmak
# -------------------------
# Data Retrieval Complete
# -------------------------
# 8

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Display the DataFrame
city_data = pd.DataFrame(city_dict)
city_data.head()
# Out:
#            City    Lat    Lng  Max temp  Humidity  Cloudiness  Wind speed  \
# 0     Dhidhdhoo   6.88  73.10    300.75        77         100        3.03
# 1         Morón -34.65 -58.62    298.15        23           0        5.10
# 2  San Patricio  28.02 -97.52    291.15        48          40        7.20
# 3  Quatre Cocos -20.21  57.76    298.71        83          75        3.60
# 4   Clyde River  70.47 -68.59    257.15        91          90        5.10
#
#   Country        Date
# 0      MV  1607286034
# 1      AR  1607286034
# 2      US  1607286034
# 3      MU  1607285786
# 4      CA  1607285786

# %%
#convert max temp from kelvin to fahrenheit
city_data["Max temp (F)"]= city_data["Max temp"] * 9/5 - 459.67

clean_city_data =city_data [["City","Lat","Lng","Max temp (F)","Humidity","Cloudiness","Wind speed","Country","Date"]]
clean_city_data.head()

#export the city data into a csv
output_path = os.path.join("output_data", "clean_city_data.csv")
city_csv=clean_city_data.to_csv(output_path, sep = ",", index=False)
# Out:
#            City    Lat    Lng  Max temp (F)  Humidity  Cloudiness  Wind speed  \
# 0     Dhidhdhoo   6.88  73.10        81.680        77         100        3.03
# 1         Morón -34.65 -58.62        77.000        23           0        5.10
# 2  San Patricio  28.02 -97.52        64.400        48          40        7.20
# 3  Quatre Cocos -20.21  57.76        78.008        83          75        3.60
# 4   Clyde River  70.47 -68.59         3.200        91          90        5.10
#
#   Country        Date
# 0      MV  1607286034
# 1      AR  1607286034
# 2      US  1607286034
# 3      MU  1607285786
# 4      CA  1607285786

# %%
satistics_summary=clean_city_data[["Lat","Lng","Max temp (F)","Humidity","Cloudiness","Wind speed","Date"]].describe()
satistics_summary
# Out:
#               Lat         Lng  Max temp (F)    Humidity  Cloudiness  \
# count  552.000000  552.000000    552.000000  552.000000  552.000000
# mean    19.883768   14.103496     54.399337   72.699275   51.309783
# std     33.422411   90.745642     27.303984   20.751581   41.262737
# min    -54.800000 -179.170000    -33.862000    1.000000    0.000000
# 25%     -8.697500  -63.562500     35.006000   64.000000    1.000000
# 50%     23.060000   15.880000     62.600000   78.000000   64.000000
# 75%     48.852500   95.522500     77.603000   88.000000   92.000000
# max     78.220000  179.320000     93.200000  100.000000  100.000000
#
#        Wind speed          Date
# count  552.000000  5.520000e+02
# mean     3.650543  1.607286e+09
# std      2.414217  2.552774e+02
# min      0.170000  1.607286e+09
# 25%      1.790000  1.607286e+09
# 50%      3.225000  1.607286e+09
# 75%      4.935000  1.607287e+09
# max     14.900000  1.607287e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.
#
# ## Maximum humidity is 100 in the satistics_summary

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# x axis
lat = clean_city_data["Lat"]

#y axis
max_temp=clean_city_data["Max temp (F)"]

# genarate the axis 
plt.scatter(lat,max_temp,color="g",edgecolors="k",alpha=1)
plt.xlabel("Latitude",fontsize=12)
plt.ylabel("Max Temperture (F)",fontsize=12)

# date of analysis
now = datetime.now()
date=now.strftime('%m/%d/%y')

plt.title(f"City Latitude vs. Temperature ({date})",fontsize=15)
plt.tight_layout()

#save the a PNG image
plt.savefig("output_data/City Latitude vs.Temperature.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat = clean_city_data["Lat"]
humidity=clean_city_data["Humidity"]

plt.scatter(lat,humidity,color="g",edgecolors="k",alpha=1)
plt.xlabel("Latitude",fontsize=12)
plt.ylabel("Humidity (%)",fontsize=12)
now = datetime.now()
date=now.strftime('%m/%d/%y')
plt.title(f"City Latitude vs. Humidity ({date})",fontsize=15)
plt.tight_layout()
plt.savefig("output_data/City Latitude vs. Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat = clean_city_data["Lat"]
cloudiness=clean_city_data["Cloudiness"]

plt.scatter(lat,cloudiness,color="g",edgecolors="k",alpha=1)
plt.xlabel("Latitude",fontsize=12)
plt.ylabel("Cloudiness (%)",fontsize=12)
now = datetime.now()
date=now.strftime('%m/%d/%y')
plt.title(f"City Latitude vs. Cloudiness ({date})",fontsize=15)
plt.tight_layout()
plt.savefig("output_data/City Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat = clean_city_data["Lat"]
wind_speed=clean_city_data["Wind speed"]

plt.scatter(lat,wind_speed,color="g",edgecolors="k",alpha=1)
plt.xlabel("Latitude",fontsize=12)
plt.ylabel("Wind Speed (mph)",fontsize=12)
now = datetime.now()
date=now.strftime('%m/%d/%y')
plt.title(f"City Latitude vs. Wind Speed ({date}) ",fontsize=15)
plt.tight_layout()
plt.savefig("output_data/City Latitude vs. Wind Speed.png")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#create dataframe for Northern Hemisphere
northern = clean_city_data[clean_city_data["Lat"] >= 0].reset_index().drop(["index"],axis=1)
northern.head()
# Out:
#               City    Lat     Lng  Max temp (F)  Humidity  Cloudiness  \
# 0        Dhidhdhoo   6.88   73.10        81.680        77         100
# 1     San Patricio  28.02  -97.52        64.400        48          40
# 2      Clyde River  70.47  -68.59         3.200        91          90
# 3        Karlskoga  59.33   14.52        44.996        93         100
# 4  Severo-Kuril'sk  50.68  156.12        27.320        90         100
#
#    Wind speed Country        Date
# 0        3.03      MV  1607286034
# 1        7.20      US  1607286034
# 2        5.10      CA  1607285786
# 3        6.70      SE  1607286034
# 4        7.34      RU  1607285784

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#create dataframe for Southern Hemisphere
southren=clean_city_data[clean_city_data["Lat"]< 0].reset_index().drop(["index"],axis=1)
southren.head()
# Out:
#            City    Lat     Lng  Max temp (F)  Humidity  Cloudiness  \
# 0         Morón -34.65  -58.62        77.000        23           0
# 1  Quatre Cocos -20.21   57.76        78.008        83          75
# 2          Chui -33.70  -53.46        65.966        57          18
# 3     Esperance -33.87  121.90        59.000        62          90
# 4         Bluff -46.60  168.33        64.994        71          28
#
#    Wind speed Country        Date
# 0        5.10      AR  1607286034
# 1        3.60      MU  1607285786
# 2        4.56      UY  1607286034
# 3        4.60      AU  1607285861
# 4        1.79      NZ  1607285791

# %%
def linear(x_axis,y_axis,x_label,y_label,title,eq_position,location):

    plt.scatter(x_axis,y_axis,color="g",edgecolors="k",alpha=1)
    plt.xlabel(x_label,fontsize=12)
    plt.ylabel(y_label,fontsize=12)
    plt.title(title,fontsize=15)

    correlation=st.pearsonr(x_axis,y_axis)
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis,y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.plot(x_axis,regress_values,"r")
    plt.annotate(line_eq,eq_position,fontsize=15,color='r')
    print(f"The r-value is: {rvalue}")
    plt.savefig(f"output_data/{location}")
    plt.show()
    return
    
linear(northern["Lat"],northern["Max temp (F)"],"Latitude","Max temp (F)","City Latitude vs. Max Temp ",(0,0),"Linear Northern City Latitude vs. Max Temp.png")
# Out:
# The r-value is: -0.864642333274557

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear(southren["Lat"],southren["Max temp (F)"],"Latitude","Max temp (F)","City Latitude vs. Max Temp ",\
(-20,53),"Linear Southern City Latitude vs. Max Temp.png")
# Out:
# The r-value is: 0.5078530369835131

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear(northern["Lat"],northern["Humidity"],"Latitude","Humidity","City Latitude vs. Humidity ",\
(45,20),"Linear Northern City Latitude vs. Humidity.png")
# Out:
# The r-value is: 0.39206797326005927

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear(southren["Lat"],southren["Humidity"],"Latitude","Humidity","City Latitude vs. Humidity ",\
(-35,40),"Linear Southern City Latitude vs. Humidity.png")
# Out:
# The r-value is: 0.3876194534852642

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear(northern["Lat"],northern["Cloudiness"],"Latitude","Cloudiness","City Latitude vs.Cloudiness ",\
(30,60),"Linear Northern City Latitude vs. Cloudiness.png")
# Out:
# The r-value is: 0.18415386784110233

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear(southren["Lat"],southren["Cloudiness"],"Latitude","Cloudiness","City Latitude vs. Cloudiness ",\
(-50,60),"Linear Southern City Latitude vs.Cloudiness.png")
# Out:
# The r-value is: 0.27941012717654684

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear(northern["Lat"],northern["Wind speed"],"Latitude","Wind speed","City Latitude vs. Wind speed ",\
(30,12),"Linear northern City Latitude vs. Wind speed.png")
# Out:
# The r-value is: 0.1322617069269053

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear(southren["Lat"],southren["Wind speed"],"Latitude","Wind speed","City Latitude vs.Wind speed ",\
(-40,10),"Linear Southern City Latitude vs. Wind speed.png")
# Out:
# The r-value is: -0.24876485592581862
